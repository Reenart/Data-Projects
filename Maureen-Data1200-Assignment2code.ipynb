# %%
#import needed libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Load HousingNew
dataset = pd.read_csv('./HousingNew.csv')
dataset.head()
# Out:
#    ID    price  lotsize  bedrooms  bathrms  stories  garagepl recroom  \
# 0   1  42000.0     5850         3        1        2         1      no
# 1   2  38500.0     4000         2        1        1         0      no
# 2   3  49500.0     3060         3        1        1         0      no
# 3   4  60500.0     6650         3        1        2         0     yes
# 4   5  61000.0     6360         2        1        1         0      no
#
#   fullbase airco
# 0      yes    no
# 1       no    no
# 2       no    no
# 3       no    no
# 4       no    no

# %%
#calculating key statistics for the HousingNew dataset, excluding ID column
dataset.drop(columns =['price']).describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 2
#       1 #calculating key statistics for the HousingNew dataset, excluding ID column
# ----> 2 dataset.drop(columns =['price']).describe()
#
# AttributeError: 'LinearRegression' object has no attribute 'drop'

# %%
#Define Independent(x) and dependent(y) variables
x=dataset[['lotsize', 'bedrooms', 'bathrms', 'stories', 'garagepl']].to_numpy()
y=dataset['price'].to_numpy()
#Create Training and Test Datasets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

#Change Data to 2D array 
x_train2 = x_train.reshape(-1,1)
x_test2 = x_test.reshape(-1,1)
y_train2 = y_train.reshape(-1,1)
y_test2 = y_test.reshape(-1,1)

# %%
#Regression Line Visualization for Lotsize and price
lmgraph=sns.regplot(x=dataset['lotsize'],y=dataset['price'])
lmgraph.axes.set_title("lot size vs price",size=20,color='black',alpha=0.5)
lmgraph.set_xlabel("Lotsize",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='red',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Regression Line Visualization for Bedrooms and price
lmgraph=sns.regplot(x=dataset['bedrooms'],y=dataset['price'])
lmgraph.axes.set_title("Bedrooms vs price",size=20,color='Purple',alpha=0.5)
lmgraph.set_xlabel("Bedrooms",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='blue',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Regression Line Visualization for bathrooms and price
lmgraph=sns.regplot(x=dataset['bathrms'],y=dataset['price'])
lmgraph.axes.set_title("Bathrooms vs price",size=20,color='Purple',alpha=0.5)
lmgraph.set_xlabel("Bathrooms",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='blue',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Regression Line Visualization for stories and price
lmgraph=sns.regplot(x=dataset['stories'],y=dataset['price'])
lmgraph.axes.set_title("Story Buildings vs Price",size=20,color='Purple',alpha=0.5)
lmgraph.set_xlabel("Stories",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='blue',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Regression Line Visualization for garagepl and price
lmgraph=sns.regplot(x=dataset['garagepl'],y=dataset['price'])
lmgraph.axes.set_title("Garage Place vs Price",size=20,color='Purple',alpha=0.5)
lmgraph.set_xlabel("Garagepl",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='blue',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#define yes and no columns as binary (0,1)
dataset['recroom'] = dataset['recroom'].map({'yes': 1, 'no': 0})
dataset['fullbase'] = dataset['fullbase'].map({'yes': 1, 'no': 0})
dataset['airco'] = dataset['airco'].map({'yes': 1, 'no': 0})

# %%
#Regression Line Visualization for garagepl and price
lmgraph=sns.regplot(x=dataset['recroom'],y=dataset['price'])
lmgraph.axes.set_title("Recroom vs Price",size=20,color='Purple',alpha=0.5)
lmgraph.set_xlabel("Recroom",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='blue',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Regression Line Visualization for garagepl and price
lmgraph=sns.regplot(x=dataset['fullbase'],y=dataset['price'])
lmgraph.axes.set_title("Fullbase vs Price",size=20,color='Purple',alpha=0.5)
lmgraph.set_xlabel("Fullbase",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='blue',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Regression Line Visualization for garagepl and price
lmgraph=sns.regplot(x=dataset['airco'],y=dataset['price'])
lmgraph.axes.set_title("Airco vs Price",size=20,color='Purple',alpha=0.5)
lmgraph.set_xlabel("Airco",size=10,color='black',alpha=0.5)
lmgraph.set_ylabel("Price",size=18,color='blue',alpha=0.5)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Create x and y variables
x = dataset.drop(columns = ['price'],axis=1).to_numpy()
y = dataset['price'].to_numpy()

#Create Train and Test Datasets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

#Scale the Data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train2 = sc.fit_transform(x_train)
x_test2 = sc.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 2
#       1 #Create x and y variables
# ----> 2 x = dataset('price',axis=1).to_numpy()
#       3 y = dataset['price'].to_numpy()
#       5 #Create Train and Test Datasets
#
# TypeError: 'LinearRegression' object is not callable

# %%
#Script for Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn import metrics  
from sklearn.metrics import r2_score

for name,dataset in [('Linear Regression', LinearRegression(n_jobs=-1))]: 
    dataset.fit(x_train2,y_train)
    predict = dataset.predict(x_test2)

print('dataset: {}'.format(name))   

#Coefficents
print('\nIntercept: {:0.2f}'.format(float(method.intercept_)))
coeff_table=pd.DataFrame(np.transpose(method.coef_),
                         dataset.drop('price',axis=1).columns,columns=['Coefficients'])
print('\n')
print(coeff_table)
    
#MAE,MSE and RMSE
print('\nR2: {:0.2f}'.format(r2_score(y_test, predict)))
adjusted_r_squared2 = 1-(1-metrics.r2_score(y_test,predict))*(len(y)-1)/(len(y)-x.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared2))

print('\nMean Absolute Error: {:0.2f}'.format(metrics.mean_absolute_error(y_test, predict)))  
print('Mean Squared Error: {:0.2f}'.format(metrics.mean_squared_error(y_test, predict)))  
print('Root Mean Squared Error: {:0.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, predict))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 7
#       4 from sklearn.metrics import r2_score
#       6 for name,dataset in [('Linear Regression', LinearRegression(n_jobs=-1))]:
# ----> 7     dataset.fit(x_train2,y_train)
#       8     predict = dataset.predict(x_test2)
#      10 print('dataset: {}'.format(name))
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd

# Assuming data contains your independent variables and 'price' is the dependent variable
X = data.drop(columns=skip_columns)  # Independent variables (excluding 'price' and skipped columns)
y = data['price']  # Dependent variable

# Fit the Linear Regression Model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Calculate key metrics
r2 = r2_score(y, y_pred)
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))

# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_

# Combine coefficients with the corresponding column names
coeff_df = pd.DataFrame({
    'Variable': X.columns,
    'Coefficient': coefficients
})

# Print the results
print("Model Coefficients:")
print(coeff_df)
print(f"Intercept: {intercept}")
print(f"R²: {r2}")
print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
